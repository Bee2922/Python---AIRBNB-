# %%
--AIR BNB DATASET - DATA CLEANING PROJECT

# %%
STEP 1 - import pandas to begin the data cleaning process

# %%
import pandas as pd

# %%
STEP 2 - Load dataset

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\Airbnb_Open_Data.csv", low_memory = False)

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
-- To view the columns in the dataset

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
STEP 2 - FILTERING DATA - Decide on what columns to keep and what columns to drop

# %%
columns_to_drop = ['id', 'reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license']

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review',]

# %%
df[columns_to_keep]
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
--Set the above table as the new dataframe

# %%
df = df[columns_to_keep]

# %%
--After saving the new dataframe, use the below code to see if the changes has been effected i.e if the number of columns has dropped or not

# %%
df.shape
# Out:
# (102599, 19)

# %%
--STEP 3: Standardise the columns. We would be renaming the columns to ensure there is consistency in how the columns are written

# %%
df = df.rename(columns = {"NAME" : "Name", "host id" : "Host Id", "host_identity_verified" : "Host_Identity_Verified", "host name" : "Host Name", "neighbourhood group" : "Neighbourhood Group", "neighbourhood" : " Neighbourhood", "lat" : "Lat", "long" : "Long", "country" : "Country", "country code" : "Country Code", "instant_bookable" : "Instant_Bookable", "cancellation_policy" : "Cancellation_Policy", "room type" : "Room Type", "Construction year" : "Construction Year", "price" : "Price", "service fee" : "Service Fee", "minimum nights" : "Minimum Nights", "number of reviews" : "Number of Reviews", "last review" : "Last Review"})

# %%
df
# Out:
#                                                     Name      Host Id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        Host_Identity_Verified    Host Name Neighbourhood Group  \
# ...

# %%
--STEP 4 - Drop duplicates

# %%
df.duplicated().sum()
# Out:
# 541

# %%
df = df.drop_duplicates()

# %%
--STEP 5 - Remove null values. To view the sum of null values in each row, use the below code

# %%
df.isna().sum()
# Out:
# Name                        250
# Host Id                       0
# Host_Identity_Verified      289
# Host Name                   404
# Neighbourhood Group          29
#  Neighbourhood               16
# Lat                           8
# Long                          8
# Country                     532
# Country Code                131
# Instant_Bookable            105
# Cancellation_Policy          76
# Room Type                     0
# Construction Year           214
# Price                       247
# Service Fee                 273
# Minimum Nights              400
# Number of Reviews           183
# Last Review               15832
# dtype: int64

# %%
To drop null values

# %%
df = df.dropna()

# %%
-- To check if null values still exists,
df.isna().sum()
# Out:
# Name                      0
# Host Id                   0
# Host_Identity_Verified    0
# Host Name                 0
# Neighbourhood Group       0
#  Neighbourhood            0
# Lat                       0
# Long                      0
# Country                   0
# Country Code              0
# Instant_Bookable          0
# Cancellation_Policy       0
# Room Type                 0
# Construction Year         0
# Price                     0
# Service Fee               0
# Minimum Nights            0
# Number of Reviews         0
# Last Review               0
# dtype: int64

# %%
df
# Out:
#                                                     Name      Host Id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        Host_Identity_Verified  Host Name Neighbourhood Group  \
# 0                 unconfirmed   Madaline            Brooklyn
# ...

# %%
df.reset_index()
# Out:
#         index                                              Name      Host Id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 83964  102029            Cozy room in a 2B with backyard access   5155155913
# 83965  102030                      An East Williamsburg Delight  71564706996
# 83966  102031                      Cozy bedroom in williamsburg  83101851929
# 83967  102032                            Spacious Room w/ 2 Bed  69037598918
# 83968  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
--To save the cleaned data in csv format

# %%
df.to_csv("Cleaned_data_wo_index.csv")

# %%
pd.read_csv(r"Cleaned_data.csv")
# Out:
#        Unnamed: 0                                              Name  \
# 0               0                Clean & quiet apt home by the park
# 1               1                             Skylit Midtown Castle
# 2               4  Entire Apt: Spacious Studio/Loft by central park
# 3               5         Large Cozy 1 BR Apartment In Midtown East
# 4               7                                   BlissArtsSpace!
# ...           ...                                               ...
# 83964      102029            Cozy room in a 2B with backyard access
# 83965      102030                      An East Williamsburg Delight
# 83966      102031                      Cozy bedroom in williamsburg
# 83967      102032                            Spacious Room w/ 2 Bed
# 83968      102040                     Room in Queens, NY, near LGA.
#
#            Host Id Host_Identity_Verified  Host Name Neighbourhood Group  \
# 0      80014485718            unconfirmed   Madaline            Brooklyn
# ...
